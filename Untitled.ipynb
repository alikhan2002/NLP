# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset.csv', encoding='utf-8')

# %%
df.head(20)
# Out:
#      syscode                              addr  \
# 0   41133795       ALM.3,TYNYSHBAYEVA STR.KUZE
# 1   00004669        TLD SAMAL 43B  UVELIR PLUS
# 2   41734346     KAR.24/1 BESIKBAYEVA ISTIKBAL
# 3   41734347     KAR.5 ALIKHANOVA POLIKOM 2030
# 4   41134221        ALM.117 FURMANOVA STR.SHOP
# 5   42433501     UST.93,KABANBAI.SHOP MICHELLE
# 6   41134222  ALM.113 56 PANFILOVA GOLD SILVER
# 7   41134224  ALM.98 PANFILOVA AGENCY FELICITY
# 8   42535876    SMP 151 NAIMANBAYEVA KANTSEROV
# 9   42036006        RDN, 50 let Oktyabrya, 66B
# 10  42036005  RDN,66B,50LETOKTYAB.,LITANYUK O.
# 11  41136008     SMK.TOGAIBAYEVA ATAMEK.ANAROV
# 12  00004800  KAZAHSTAN, ALMATY G, AKBULAK UL,
# 13  72040292      RDN.60 LENINA.BEAUTYPROFLINE
# 14  41140293       ALM.10.52 ZHETYSU 4.INSSARS
# 15  41236007     AST VP7,13,ALMATY MIR SANARIO
# 16  71138644    AST.8 IMANBAYEVA .ALMAGEST BIZ
# 17  71138645        ALM.28 KABDOLOVA.ROD DOM 5
# 18  71138576     ALM.221 A RAYMBEKA.VET EFFECT
# ...

# %%
df.tail(10)
# Out:
#           syscode                              addr  \
# 59497    40135690              ALMATY G, ALTYN ORDA
# 59498  17-5642-L3  KAZAHSTAN, ZHAMBYLSKAYA OBL, TAR
# 59499    41931881              URL UL.SHEVCHENKO 54
# 59500    41331671          PVL UL.ESTAYA 99 BUTIK 6
# 59501  02-6478-L3  KAZAHSTAN, ALMATY G, ZHETYSUSKIJ
# 59502  02-6480-L3  KAZAHSTAN, ALMATY G, ZHETYSUSKIJ
# 59503    40135694             ALMATY G, AL-FARABI U
# 59504    40135695  KAZAHSTAN, ALMATY G, AL-FARABI U
# 59505    40135696             ALMATY G, RYSKULOVA U
# 59506    40135697             ALMATY G, ABAYA UL, D
#
#                                                    descr  \
# 59497                                        ИП Казезова
# 59498                                  ИП Молдатаев Ж.Г.
# 59499                                        ИП "Нуртай"
# 59500                                         ИП Карамат
# 59501                                       ИП ИЛАХУНОВА
# ...

# %%
df.to_excel('dataset.xlsx', index=False)

# %%
# !pip install openpyxl
